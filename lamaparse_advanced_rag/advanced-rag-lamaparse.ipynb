# %% [markdown]
# # Advanced RAG with LlamaParse
#
# <a href="https://colab.research.google.com/github/run-llama/llama_parse/blob/main/examples/demo_advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# This notebook is a complete walkthrough for using LlamaParse with advanced indexing/retrieval techniques in LlamaIndex over the Apple 10K Filing.
#
# This allows us to ask sophisticated questions that aren't possible with "naive" parsing/indexing techniques with existing models.
#
# Note for this example, we are using the `llama_index >=0.10.4` version

# %%
# !pip install llama-index
# !pip install llama-index-core==0.10.6.post1
# !pip install llama-index-embeddings-openai
# !pip install llama-index-postprocessor-flag-embedding-reranker
# !pip install git+https://github.com/FlagOpen/FlagEmbedding.git
# !pip install llama-parse
# Out:
# Collecting llama-index
#   Downloading llama_index-0.11.14-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-agent-openai<0.4.0,>=0.3.4 (from llama-index)
#   Downloading llama_index_agent_openai-0.3.4-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-cli<0.4.0,>=0.3.1 (from llama-index)
#   Downloading llama_index_cli-0.3.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core<0.12.0,>=0.11.14 (from llama-index)
#   Downloading llama_index_core-0.11.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting llama-index-embeddings-openai<0.3.0,>=0.2.4 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.2.5-py3-none-any.whl.metadata (686 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.3.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.4.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.3.0,>=0.2.9 (from llama-index)
#   Downloading llama_index_llms_openai-0.2.9-py3-none-any.whl.metadata (648 bytes)
# Collecting llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.2.1-py3-none-any.whl.metadata (728 bytes)
# Collecting llama-index-program-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_program_openai-0.2.0-py3-none-any.whl.metadata (766 bytes)
# Collecting llama-index-question-gen-openai<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.3.0,>=0.2.0 (from llama-index)
#   Downloading llama_index_readers_file-0.2.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.3.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting nltk>3.8.1 (from llama-index)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting openai>=1.14.0 (from llama-index-agent-openai<0.4.0,>=0.3.4->llama-index)
#   Downloading openai-1.50.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.14->llama-index) (6.0.2)
# Collecting SQLAlchemy>=1.4.49 (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading SQLAlchemy-2.0.35-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.6 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading aiohttp-3.10.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.6 kB)
# Collecting dataclasses-json (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting fsspec>=2023.5.0 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting httpx (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting nest-asyncio<2.0.0,>=1.5.8 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting networkx>=3.0 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting numpy<2.0.0 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Collecting pillow>=9.0.0 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pydantic<3.0.0,>=2.7.0 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting requests>=2.31.0 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.2.0 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading tiktoken-0.7.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting tqdm<5.0.0,>=4.66.1 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting typing-extensions>=4.5.0 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting wrapt (from llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading wrapt-1.16.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting llama-cloud>=0.0.11 (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index)
#   Downloading llama_cloud-0.1.0-py3-none-any.whl.metadata (750 bytes)
# Collecting pandas (from llama-index-legacy<0.10.0,>=0.9.48->llama-index)
#   Downloading pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (89 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in ./venv/lib/python3.12/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Downloading pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.3.0->llama-index)
#   Downloading llama_parse-0.5.6-py3-none-any.whl.metadata (6.1 kB)
# Collecting click (from nltk>3.8.1->llama-index)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk>3.8.1->llama-index)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk>3.8.1->llama-index)
#   Downloading regex-2024.9.11-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading aiohappyeyeballs-2.4.2-py3-none-any.whl.metadata (6.0 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Using cached frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading multidict-6.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Collecting yarl<2.0,>=1.12.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading yarl-1.13.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (50 kB)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.6)
# Requirement already satisfied: anyio in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (4.6.0)
# Collecting certifi (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting httpcore==1.* (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (3.10)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.14->llama-index) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting distro<2,>=1.7.0 (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.4->llama-index)
#   Downloading jiter-0.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading pydantic_core-2.23.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading greenlet-3.1.1-cp312-cp312-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.12.0,>=0.11.14->llama-index)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: packaging>=17.0 in ./venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.14->llama-index) (24.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Downloading llama_index-0.11.14-py3-none-any.whl (6.8 kB)
# Downloading llama_index_agent_openai-0.3.4-py3-none-any.whl (13 kB)
# Downloading llama_index_cli-0.3.1-py3-none-any.whl (27 kB)
# Downloading llama_index_core-0.11.14-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.7 MB/s eta 0:00:00
# Downloading llama_index_embeddings_openai-0.2.5-py3-none-any.whl (6.1 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.4.0-py3-none-any.whl (10 kB)
# Downloading llama_index_legacy-0.9.48.post3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.8 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.2.9-py3-none-any.whl (12 kB)
# Downloading llama_index_multi_modal_llms_openai-0.2.1-py3-none-any.whl (5.9 kB)
# Downloading llama_index_program_openai-0.2.0-py3-none-any.whl (5.3 kB)
# Downloading llama_index_question_gen_openai-0.2.0-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.2.2-py3-none-any.whl (38 kB)
# Downloading llama_index_readers_llama_parse-0.3.0-py3-none-any.whl (2.5 kB)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 26.1 MB/s eta 0:00:00
# Downloading aiohttp-3.10.6-cp312-cp312-macosx_11_0_arm64.whl (390 kB)
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Downloading llama_cloud-0.1.0-py3-none-any.whl (176 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
# Downloading llama_parse-0.5.6-py3-none-any.whl (10 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 29.8 MB/s eta 0:00:0031m30.3 MB/s eta 0:00:01
# Downloading openai-1.50.1-py3-none-any.whl (378 kB)
# Downloading pillow-10.4.0-cp312-cp312-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 28.7 MB/s eta 0:00:00
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 27.8 MB/s eta 0:00:00
# Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
# Downloading regex-2024.9.11-cp312-cp312-macosx_11_0_arm64.whl (284 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading SQLAlchemy-2.0.35-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.9 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.7.0-cp312-cp312-macosx_11_0_arm64.whl (906 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.7/906.7 kB 22.5 MB/s eta 0:00:00
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading wrapt-1.16.0-cp312-cp312-macosx_11_0_arm64.whl (38 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 29.8 MB/s eta 0:00:00MB/s eta 0:00:01
# Downloading aiohappyeyeballs-2.4.2-py3-none-any.whl (14 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl (119 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
# Downloading greenlet-3.1.1-cp312-cp312-macosx_11_0_universal2.whl (274 kB)
# Downloading jiter-0.5.0-cp312-cp312-macosx_11_0_arm64.whl (296 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
# Downloading multidict-6.1.0-cp312-cp312-macosx_11_0_arm64.whl (29 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading yarl-1.13.0-cp312-cp312-macosx_11_0_arm64.whl (113 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: striprtf, pytz, dirtyjson, wrapt, urllib3, tzdata, typing-extensions, tqdm, tenacity, regex, pypdf, pillow, numpy, networkx, nest-asyncio, mypy-extensions, multidict, marshmallow, joblib, jiter, h11, greenlet, fsspec, frozenlist, distro, click, charset-normalizer, certifi, annotated-types, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, requests, pydantic-core, pandas, nltk, httpcore, deprecated, aiosignal, tiktoken, pydantic, httpx, dataclasses-json, aiohttp, openai, llama-index-core, llama-cloud, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-legacy, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index
# Successfully installed SQLAlchemy-2.0.35 aiohappyeyeballs-2.4.2 aiohttp-3.10.6 aiosignal-1.3.1 annotated-types-0.7.0 certifi-2024.8.30 charset-normalizer-3.3.2 click-8.1.7 dataclasses-json-0.6.7 deprecated-1.2.14 dirtyjson-1.0.8 distro-1.9.0 frozenlist-1.4.1 fsspec-2024.9.0 greenlet-3.1.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jiter-0.5.0 joblib-1.4.2 llama-cloud-0.1.0 llama-index-0.11.14 llama-index-agent-openai-0.3.4 llama-index-cli-0.3.1 llama-index-core-0.11.14 llama-index-embeddings-openai-0.2.5 llama-index-indices-managed-llama-cloud-0.4.0 llama-index-legacy-0.9.48.post3 llama-index-llms-openai-0.2.9 llama-index-multi-modal-llms-openai-0.2.1 llama-index-program-openai-0.2.0 llama-index-question-gen-openai-0.2.0 llama-index-readers-file-0.2.2 llama-index-readers-llama-parse-0.3.0 llama-parse-0.5.6 marshmallow-3.22.0 multidict-6.1.0 mypy-extensions-1.0.0 nest-asyncio-1.6.0 networkx-3.3 nltk-3.9.1 numpy-1.26.4 openai-1.50.1 pandas-2.2.3 pillow-10.4.0 pydantic-2.9.2 pydantic-core-2.23.4 pypdf-4.3.1 pytz-2024.2 regex-2024.9.11 requests-2.32.3 striprtf-0.0.26 tenacity-8.5.0 tiktoken-0.7.0 tqdm-4.66.5 typing-extensions-4.12.2 typing-inspect-0.9.0 tzdata-2024.2 urllib3-2.2.3 wrapt-1.16.0 yarl-1.13.0
# Collecting llama-index-core==0.10.6.post1
#   Downloading llama_index_core-0.10.6.post1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.6.post1) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (3.10.6)
# Requirement already satisfied: dataclasses-json in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (2024.9.0)
# Requirement already satisfied: httpx in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (0.27.2)
# Collecting llamaindex-py-client>=0.1.12 (from llama-index-core==0.10.6.post1)
#   Downloading llamaindex_py_client-0.1.19-py3-none-any.whl.metadata (760 bytes)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (3.9.1)
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (1.50.1)
# Requirement already satisfied: pandas in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (2.2.3)
# Requirement already satisfied: pillow>=9.0.0 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (10.4.0)
# Requirement already satisfied: requests>=2.31.0 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./venv/lib/python3.12/site-packages (from llama-index-core==0.10.6.post1) (0.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.6.post1) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.6.post1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.6.post1) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.6.post1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.6.post1) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.6.post1) (1.13.0)
# Requirement already satisfied: wrapt<2,>=1.10 in ./venv/lib/python3.12/site-packages (from deprecated>=1.2.9.3->llama-index-core==0.10.6.post1) (1.16.0)
# Requirement already satisfied: pydantic>=1.10 in ./venv/lib/python3.12/site-packages (from llamaindex-py-client>=0.1.12->llama-index-core==0.10.6.post1) (2.9.2)
# Requirement already satisfied: anyio in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core==0.10.6.post1) (4.6.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core==0.10.6.post1) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core==0.10.6.post1) (1.0.5)
# Requirement already satisfied: idna in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core==0.10.6.post1) (3.10)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core==0.10.6.post1) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.6.post1) (0.14.0)
# Requirement already satisfied: click in ./venv/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.6.post1) (8.1.7)
# Requirement already satisfied: joblib in ./venv/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.6.post1) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./venv/lib/python3.12/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.6.post1) (2024.9.11)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-core==0.10.6.post1) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-core==0.10.6.post1) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core==0.10.6.post1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core==0.10.6.post1) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in ./venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.6.post1) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.6.post1) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core==0.10.6.post1) (3.22.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas->llama-index-core==0.10.6.post1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.12/site-packages (from pandas->llama-index-core==0.10.6.post1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas->llama-index-core==0.10.6.post1) (2024.2)
# Requirement already satisfied: packaging>=17.0 in ./venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.6.post1) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic>=1.10->llamaindex-py-client>=0.1.12->llama-index-core==0.10.6.post1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./venv/lib/python3.12/site-packages (from pydantic>=1.10->llamaindex-py-client>=0.1.12->llama-index-core==0.10.6.post1) (2.23.4)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.6.post1) (1.16.0)
# Downloading llama_index_core-0.10.6.post1-py3-none-any.whl (15.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 8.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading llamaindex_py_client-0.1.19-py3-none-any.whl (141 kB)
# Installing collected packages: llamaindex-py-client, llama-index-core
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.11.14
#     Uninstalling llama-index-core-0.11.14:
#       Successfully uninstalled llama-index-core-0.11.14
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-question-gen-openai 0.2.0 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-index-program-openai 0.2.0 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-index-indices-managed-llama-cloud 0.4.0 requires llama-index-core<0.12.0,>=0.11.13.post1, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-index-agent-openai 0.3.4 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-index-embeddings-openai 0.2.5 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-index-cli 0.3.1 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-index-readers-llama-parse 0.3.0 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-parse 0.5.6 requires llama-index-core>=0.11.0, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-index-llms-openai 0.2.9 requires llama-index-core<0.12.0,>=0.11.7, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-index-multi-modal-llms-openai 0.2.1 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-index-readers-file 0.2.2 requires llama-index-core<0.12.0,>=0.11.0, but you have llama-index-core 0.10.6.post1 which is incompatible.
# llama-index 0.11.14 requires llama-index-core<0.12.0,>=0.11.14, but you have llama-index-core 0.10.6.post1 which is incompatible.
# Successfully installed llama-index-core-0.10.6.post1 llamaindex-py-client-0.1.19
# Requirement already satisfied: llama-index-embeddings-openai in ./venv/lib/python3.12/site-packages (0.2.5)
# Collecting llama-index-core<0.12.0,>=0.11.0 (from llama-index-embeddings-openai)
#   Using cached llama_index_core-0.11.14-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: openai>=1.1.0 in ./venv/lib/python3.12/site-packages (from llama-index-embeddings-openai) (1.50.1)
# Requirement already satisfied: PyYAML>=6.0.1 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.10.6)
# Requirement already satisfied: dataclasses-json in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2024.9.0)
# Requirement already satisfied: httpx in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.3)
# Requirement already satisfied: nltk>3.8.1 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: wrapt in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (0.5.0)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.13.0)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai) (3.10)
# Requirement already satisfied: certifi in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: click in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (8.1.7)
# Requirement already satisfied: joblib in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in ./venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (3.22.0)
# Requirement already satisfied: packaging>=17.0 in ./venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-embeddings-openai) (24.1)
# Using cached llama_index_core-0.11.14-py3-none-any.whl (1.6 MB)
# Installing collected packages: llama-index-core
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.10.6.post1
#     Uninstalling llama-index-core-0.10.6.post1:
#       Successfully uninstalled llama-index-core-0.10.6.post1
# Successfully installed llama-index-core-0.11.14
# Collecting llama-index-postprocessor-flag-embedding-reranker
#   Downloading llama_index_postprocessor_flag_embedding_reranker-0.2.0-py3-none-any.whl.metadata (714 bytes)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in ./venv/lib/python3.12/site-packages (from llama-index-postprocessor-flag-embedding-reranker) (0.11.14)
# Requirement already satisfied: PyYAML>=6.0.1 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (3.10.6)
# Requirement already satisfied: dataclasses-json in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (2024.9.0)
# Requirement already satisfied: httpx in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (3.3)
# Requirement already satisfied: nltk>3.8.1 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (0.9.0)
# Requirement already satisfied: wrapt in ./venv/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.13.0)
# Requirement already satisfied: click in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (8.1.7)
# Requirement already satisfied: joblib in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in ./venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (3.22.0)
# Requirement already satisfied: anyio in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (4.6.0)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.0.5)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in ./venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-postprocessor-flag-embedding-reranker) (24.1)
# Downloading llama_index_postprocessor_flag_embedding_reranker-0.2.0-py3-none-any.whl (3.0 kB)
# Installing collected packages: llama-index-postprocessor-flag-embedding-reranker
# Successfully installed llama-index-postprocessor-flag-embedding-reranker-0.2.0
# Collecting git+https://github.com/FlagOpen/FlagEmbedding.git
#   Cloning https://github.com/FlagOpen/FlagEmbedding.git to /private/var/folders/cd/5sh47r5n353c5vt5sgpc713h0000gn/T/pip-req-build-vynnfsou
#   Running command git clone --filter=blob:none --quiet https://github.com/FlagOpen/FlagEmbedding.git /private/var/folders/cd/5sh47r5n353c5vt5sgpc713h0000gn/T/pip-req-build-vynnfsou
#   Resolved https://github.com/FlagOpen/FlagEmbedding.git to commit 43d4154fcc6b049a475a0f4fb3fc0051851c79f8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting torch>=1.6.0 (from FlagEmbedding==1.2.11)
#   Downloading torch-2.4.1-cp312-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Collecting transformers>=4.33.0 (from FlagEmbedding==1.2.11)
#   Downloading transformers-4.45.1-py3-none-any.whl.metadata (44 kB)
# Collecting datasets (from FlagEmbedding==1.2.11)
#   Downloading datasets-3.0.1-py3-none-any.whl.metadata (20 kB)
# Collecting accelerate>=0.20.1 (from FlagEmbedding==1.2.11)
#   Downloading accelerate-0.34.2-py3-none-any.whl.metadata (19 kB)
# Collecting sentence-transformers (from FlagEmbedding==1.2.11)
#   Downloading sentence_transformers-3.1.1-py3-none-any.whl.metadata (10 kB)
# Collecting peft (from FlagEmbedding==1.2.11)
#   Downloading peft-0.13.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in ./venv/lib/python3.12/site-packages (from accelerate>=0.20.1->FlagEmbedding==1.2.11) (1.26.4)
# ...
# Collecting safetensors>=0.4.3 (from accelerate>=0.20.1->FlagEmbedding==1.2.11)
#   Downloading safetensors-0.4.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting filelock (from torch>=1.6.0->FlagEmbedding==1.2.11)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./venv/lib/python3.12/site-packages (from torch>=1.6.0->FlagEmbedding==1.2.11) (4.12.2)
# Collecting sympy (from torch>=1.6.0->FlagEmbedding==1.2.11)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in ./venv/lib/python3.12/site-packages (from torch>=1.6.0->FlagEmbedding==1.2.11) (3.3)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.12/site-packages (from torch>=1.6.0->FlagEmbedding==1.2.11) (3.1.4)
# Requirement already satisfied: fsspec in ./venv/lib/python3.12/site-packages (from torch>=1.6.0->FlagEmbedding==1.2.11) (2024.9.0)
# Collecting setuptools (from torch>=1.6.0->FlagEmbedding==1.2.11)
#   Using cached setuptools-75.1.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: regex!=2019.12.17 in ./venv/lib/python3.12/site-packages (from transformers>=4.33.0->FlagEmbedding==1.2.11) (2024.9.11)
# Requirement already satisfied: requests in ./venv/lib/python3.12/site-packages (from transformers>=4.33.0->FlagEmbedding==1.2.11) (2.32.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers>=4.33.0->FlagEmbedding==1.2.11)
#   Downloading tokenizers-0.20.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in ./venv/lib/python3.12/site-packages (from transformers>=4.33.0->FlagEmbedding==1.2.11) (4.66.5)
# Collecting pyarrow>=15.0.0 (from datasets->FlagEmbedding==1.2.11)
#   Downloading pyarrow-17.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->FlagEmbedding==1.2.11)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in ./venv/lib/python3.12/site-packages (from datasets->FlagEmbedding==1.2.11) (2.2.3)
# Collecting xxhash (from datasets->FlagEmbedding==1.2.11)
#   Downloading xxhash-3.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->FlagEmbedding==1.2.11)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch>=1.6.0->FlagEmbedding==1.2.11)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in ./venv/lib/python3.12/site-packages (from datasets->FlagEmbedding==1.2.11) (3.10.6)
# Collecting scikit-learn (from sentence-transformers->FlagEmbedding==1.2.11)
#   Downloading scikit_learn-1.5.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (13 kB)
# Collecting scipy (from sentence-transformers->FlagEmbedding==1.2.11)
#   Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: Pillow in ./venv/lib/python3.12/site-packages (from sentence-transformers->FlagEmbedding==1.2.11) (10.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->FlagEmbedding==1.2.11) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->FlagEmbedding==1.2.11) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->FlagEmbedding==1.2.11) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->FlagEmbedding==1.2.11) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->FlagEmbedding==1.2.11) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./venv/lib/python3.12/site-packages (from aiohttp->datasets->FlagEmbedding==1.2.11) (1.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests->transformers>=4.33.0->FlagEmbedding==1.2.11) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests->transformers>=4.33.0->FlagEmbedding==1.2.11) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests->transformers>=4.33.0->FlagEmbedding==1.2.11) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests->transformers>=4.33.0->FlagEmbedding==1.2.11) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.12/site-packages (from jinja2->torch>=1.6.0->FlagEmbedding==1.2.11) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas->datasets->FlagEmbedding==1.2.11) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.12/site-packages (from pandas->datasets->FlagEmbedding==1.2.11) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas->datasets->FlagEmbedding==1.2.11) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers->FlagEmbedding==1.2.11) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers->FlagEmbedding==1.2.11)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.6.0->FlagEmbedding==1.2.11)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets->FlagEmbedding==1.2.11) (1.16.0)
# Downloading accelerate-0.34.2-py3-none-any.whl (324 kB)
# Downloading torch-2.4.1-cp312-none-macosx_11_0_arm64.whl (62.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 MB 24.3 MB/s eta 0:00:0031m24.6 MB/s eta 0:00:01
# Downloading transformers-4.45.1-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 29.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading datasets-3.0.1-py3-none-any.whl (471 kB)
# Downloading peft-0.13.0-py3-none-any.whl (322 kB)
# Downloading sentence_transformers-3.1.1-py3-none-any.whl (245 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Downloading huggingface_hub-0.25.1-py3-none-any.whl (436 kB)
# Downloading pyarrow-17.0.0-cp312-cp312-macosx_11_0_arm64.whl (27.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 26.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading safetensors-0.4.5-cp312-cp312-macosx_11_0_arm64.whl (381 kB)
# Downloading tokenizers-0.20.0-cp312-cp312-macosx_11_0_arm64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 13.8 MB/s eta 0:00:00
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading psutil-6.0.0-cp38-abi3-macosx_11_0_arm64.whl (251 kB)
# Downloading scikit_learn-1.5.2-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 13.3 MB/s eta 0:00:00m eta 0:00:01:01:01
# Downloading scipy-1.14.1-cp312-cp312-macosx_14_0_arm64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 7.9 MB/s eta 0:00:000:00:01m eta 0:00:01
# Using cached setuptools-75.1.0-py3-none-any.whl (1.2 MB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 10.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading xxhash-3.5.0-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: FlagEmbedding
#   Building wheel for FlagEmbedding (pyproject.toml) ... done
#   Created wheel for FlagEmbedding: filename=FlagEmbedding-1.2.11-py3-none-any.whl size=1533326 sha256=21b35df8e0878c1c87f3304910add324a792e39d70d3e24d2d8c83edc73e966d
#   Stored in directory: /private/var/folders/cd/5sh47r5n353c5vt5sgpc713h0000gn/T/pip-ephem-wheel-cache-92petp2j/wheels/16/8c/62/ed54563af3e29af1a4c10f80e92b0cd08993cedb4085c96fda
# Successfully built FlagEmbedding
# Installing collected packages: mpmath, xxhash, threadpoolctl, sympy, setuptools, scipy, safetensors, pyarrow, psutil, fsspec, filelock, dill, torch, scikit-learn, multiprocess, huggingface-hub, tokenizers, accelerate, transformers, datasets, sentence-transformers, peft, FlagEmbedding
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.9.0
#     Uninstalling fsspec-2024.9.0:
#       Successfully uninstalled fsspec-2024.9.0
# Successfully installed FlagEmbedding-1.2.11 accelerate-0.34.2 datasets-3.0.1 dill-0.3.8 filelock-3.16.1 fsspec-2024.6.1 huggingface-hub-0.25.1 mpmath-1.3.0 multiprocess-0.70.16 peft-0.13.0 psutil-6.0.0 pyarrow-17.0.0 safetensors-0.4.5 scikit-learn-1.5.2 scipy-1.14.1 sentence-transformers-3.1.1 setuptools-75.1.0 sympy-1.13.3 threadpoolctl-3.5.0 tokenizers-0.20.0 torch-2.4.1 transformers-4.45.1 xxhash-3.5.0
# Requirement already satisfied: llama-parse in ./venv/lib/python3.12/site-packages (0.5.6)
# Requirement already satisfied: llama-index-core>=0.11.0 in ./venv/lib/python3.12/site-packages (from llama-parse) (0.11.14)
# Requirement already satisfied: PyYAML>=6.0.1 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in ./venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core>=0.11.0->llama-parse) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (3.10.6)
# Requirement already satisfied: dataclasses-json in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (2024.6.1)
# Requirement already satisfied: httpx in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (3.3)
# Requirement already satisfied: nltk>3.8.1 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (0.9.0)
# Requirement already satisfied: wrapt in ./venv/lib/python3.12/site-packages (from llama-index-core>=0.11.0->llama-parse) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core>=0.11.0->llama-parse) (1.13.0)
# Requirement already satisfied: click in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core>=0.11.0->llama-parse) (8.1.7)
# Requirement already satisfied: joblib in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core>=0.11.0->llama-parse) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./venv/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core>=0.11.0->llama-parse) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core>=0.11.0->llama-parse) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core>=0.11.0->llama-parse) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core>=0.11.0->llama-parse) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core>=0.11.0->llama-parse) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core>=0.11.0->llama-parse) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core>=0.11.0->llama-parse) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in ./venv/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core>=0.11.0->llama-parse) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core>=0.11.0->llama-parse) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.12/site-packages (from dataclasses-json->llama-index-core>=0.11.0->llama-parse) (3.22.0)
# Requirement already satisfied: anyio in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core>=0.11.0->llama-parse) (4.6.0)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core>=0.11.0->llama-parse) (1.0.5)
# Requirement already satisfied: sniffio in ./venv/lib/python3.12/site-packages (from httpx->llama-index-core>=0.11.0->llama-parse) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core>=0.11.0->llama-parse) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in ./venv/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core>=0.11.0->llama-parse) (24.1)

# %%
# !wget "https://s2.q4cdn.com/470004039/files/doc_financials/2021/q4/_10-K-2021-(As-Filed).pdf" -O apple_2021_10k.pdf
# Out:
# --2024-09-27 17:57:08--  https://s2.q4cdn.com/470004039/files/doc_financials/2021/q4/_10-K-2021-(As-Filed).pdf
# Resolving s2.q4cdn.com (s2.q4cdn.com)... 185.172.148.132
# Connecting to s2.q4cdn.com (s2.q4cdn.com)|185.172.148.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 789896 (771K) [application/pdf]
# Saving to: ‘apple_2021_10k.pdf’
#
# apple_2021_10k.pdf  100%[===================>] 771.38K  3.00MB/s    in 0.3s
#
# 2024-09-27 17:57:09 (3.00 MB/s) - ‘apple_2021_10k.pdf’ saved [789896/789896]

# %% [markdown]
# Some OpenAI and LlamaParse details

# %%
# llama-parse is async-first, running the async code in a notebook requires the use of nest_asyncio
import nest_asyncio

nest_asyncio.apply()

import os

# API access to llama-cloud
os.environ["LLAMA_CLOUD_API_KEY"] = "llx-..."

# Using OpenAI API for embeddings/llms
os.environ["OPENAI_API_KEY"] = "sk-..."

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex
from llama_index.core import Settings

embed_model = OpenAIEmbedding(model="text-embedding-3-small")
llm = OpenAI(model="gpt-3.5-turbo-0125")

Settings.llm = llm
Settings.embed_model = embed_model

# %% [markdown]
# ## Using brand new `LlamaParse` PDF reader for PDF Parsing
#
# we also compare two different retrieval/query engine strategies:
# 1. Using raw Markdown text as nodes for building index and apply simple query engine for generating the results;
# 2. Using `MarkdownElementNodeParser` for parsing the `LlamaParse` output Markdown results and building recursive retriever query engine for generation.

# %%
from llama_parse import LlamaParse

documents = LlamaParse(result_type="markdown").load_data("./apple_2021_10k.pdf")
# Out:
# Started parsing the file under job_id cac11eca-71db-4dab-b72b-c67d31e551f3

# %%
from copy import deepcopy
from llama_index.core.schema import TextNode
from llama_index.core import VectorStoreIndex


def get_page_nodes(docs, separator="\n---\n"):
    """Split each document into page node, by separator."""
    nodes = []
    for doc in docs:
        doc_chunks = doc.text.split(separator)
        for doc_chunk in doc_chunks:
            node = TextNode(
                text=doc_chunk,
                metadata=deepcopy(doc.metadata),
            )
            nodes.append(node)

    return nodes

# %%
page_nodes = get_page_nodes(documents)

# %%
from llama_index.core.node_parser import MarkdownElementNodeParser

node_parser = MarkdownElementNodeParser(
    llm=OpenAI(model="gpt-3.5-turbo-0125"), num_workers=8
)

# %%
nodes = node_parser.get_nodes_from_documents(documents)

# %%
base_nodes, objects = node_parser.get_nodes_and_objects(nodes)

# %%
objects[0].get_content()
# Out:
# "This table provides information about a company's state of incorporation or organization and its corresponding I.R.S. Employer Identification Number.,\nwith the following table title:\nCompany Incorporation Information,\nwith the following columns:\n- California: None\n- 94-2404110: None\n"

# %%
# dump both indexed tables and page text into the vector index
recursive_index = VectorStoreIndex(nodes=base_nodes + objects + page_nodes)

# %%
print(page_nodes[31].get_content())
# Out:
# # Apple Inc.
#
# **CONSOLIDATED STATEMENTS OF OPERATIONS (In millions, except number of shares which are reflected in thousands and per share amounts)**
# | |September 25, 2021|September 26, 2020|September 28, 2019|
# |---|---|---|---|
# |Net sales:|$297,392|$220,747|$213,883|
# |Products| | | |
# |Services|$68,425|$53,768|$46,291|
# |Total net sales|$365,817|$274,515|$260,174|
# |Cost of sales:| | | |
# |Products|$192,266|$151,286|$144,996|
# |Services|$20,715|$18,273|$16,786|
# |Total cost of sales|$212,981|$169,559|$161,782|
# |Gross margin|$152,836|$104,956|$98,392|
# |Operating expenses:| | | |
# |Research and development|$21,914|$18,752|$16,217|
# |Selling, general and administrative|$21,973|$19,916|$18,245|
# |Total operating expenses|$43,887|$38,668|$34,462|
# |Operating income|$108,949|$66,288|$63,930|
# |Other income/(expense), net|$258|$803|$1,807|
# |Income before provision for income taxes|$109,207|$67,091|$65,737|
# |Provision for income taxes|$14,527|$9,680|$10,481|
# |Net income|$94,680|$57,411|$55,256|
# |Earnings per share:| | | |
# |Basic|$5.67|$3.31|$2.99|
# |Diluted|$5.61|$3.28|$2.97|
# |Shares used in computing earnings per share:| | | |
# |Basic|16,701,272|17,352,119|18,471,336|
# |Diluted|16,864,919|17,528,214|18,595,651|
#
# See accompanying Notes to Consolidated Financial Statements.

# %%
from llama_index.postprocessor.flag_embedding_reranker import FlagEmbeddingReranker

reranker = FlagEmbeddingReranker(
    top_n=5,
    model="BAAI/bge-reranker-large",
)

recursive_query_engine = recursive_index.as_query_engine(
    similarity_top_k=5, node_postprocessors=[reranker], verbose=True
)

# %%
print(len(nodes))
# Out:
# 233

# %% [markdown]
# ## Setup Baseline
#
# For comparison, we setup a naive RAG pipeline with default parsing and standard chunking, indexing, retrieval.

# %%
from llama_index.core import SimpleDirectoryReader

reader = SimpleDirectoryReader(input_files=["apple_2021_10k.pdf"])
base_docs = reader.load_data()
raw_index = VectorStoreIndex.from_documents(base_docs)
raw_query_engine = raw_index.as_query_engine(
    similarity_top_k=5, node_postprocessors=[reranker]
)

# %% [markdown]
# ## Using `new LlamaParse` as pdf data parsing methods and retrieve tables with two different methods
# we compare base query engine vs recursive query engine with tables

# %% [markdown]
# ### Table Query Task: Queries for Table Question Answering

# %%
query = "Purchases of marketable securities in 2020"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# The purchases of marketable securities in 2020 amounted to $163.4 billion.
# Retrieval entering 59368b87-e602-4bd1-88a7-7526fd6ab83f: TextNode
# Retrieving from object TextNode with query Purchases of marketable securities in 2020
# Retrieval entering dfd97f47-eb4d-4bab-8a22-9bbbc0096a4b: TextNode
# Retrieving from object TextNode with query Purchases of marketable securities in 2020
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# $114,938

# %%
print(response_2.source_nodes[2].get_content())
# Out:
# This table provides information on hedged assets and liabilities for the years 2021 and 2020, including current and non-current marketable securities and term debt.,
# with the following table title:
# Hedged Assets and Liabilities Summary,
# with the following columns:
# - 2021: None
# - 2020: None
#
# | |2021|2020|
# |---|---|---|
# |Hedged assets/(liabilities):| | |
# |Current and non-current marketable securities|$15,954|$16,270|
# |Current and non-current term debt|$(17,857)|$(21,033)|

# %%
query = "effective interest rates of all debt issuances in 2021"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# 0.03%, 0.75%, 1.43%
# Retrieval entering a5afa785-217f-4e72-87cf-15da11632ec0: TextNode
# Retrieving from object TextNode with query effective interest rates of all debt issuances in 2021
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# 0.48% – 0.63%, 0.03% – 4.78%, 0.75% – 2.81%, 1.43% – 2.86%

# %%
print(response_1.source_nodes[0].get_content())
# Out:
# Term Debt
# As of September 25, 2021 , the Company had outstanding floating- and fixed-rate notes with varying maturities for an aggregate
# principal amount of $118.1 billion  (collectively the “Notes”). The Notes are senior unsecured obligations and interest is payable in
# arrears. The following table provides a summary of the Company’s term debt as of September 25, 2021  and September 26,
# 2020 :
# Maturities
# (calendar year)2021 2020
# Amount
# (in millions)Effective
# Interest RateAmount
# (in millions)Effective
# Interest Rate
# 2013 – 2020 debt issuances:
# Floating-rate notes  2022 $ 1,750 0.48%  – 0.63% $ 2,250 0.60%  – 1.39%
# Fixed-rate 0.000%  – 4.650%  notes 2022  – 2060  95,813 0.03%  – 4.78%  103,828 0.03%  – 4.78%
# Second quarter 2021 debt issuance:
# Fixed-rate 0.700%  – 2.800%  notes 2026  – 2061  14,000 0.75%  – 2.81%  —  — %
# Fourth quarter 2021 debt issuance:
# Fixed-rate 1.400%  – 2.850%  notes 2028  – 2061  6,500 1.43%  – 2.86%  —  — %
# Total term debt  118,063  106,078
# Unamortized premium/(discount) and issuance
# costs, net  (380)  (314)
# Hedge accounting fair value adjustments  1,036  1,676
# Less: Current portion of term debt  (9,613)  (8,773)
# Total non-current portion of term debt $ 109,106 $ 98,667
# To manage interest rate risk on certain of its U.S. dollar–denominated fixed- or floating-rate notes, the Company has entered into
# interest rate swaps to effectively convert the fixed interest rates to floating interest rates or the floating interest rates to fixed
# interest rates on a portion of these notes. Additionally, to manage foreign currency risk on certain of its foreign currency–
# denominated notes, the Company has entered into foreign currency swaps to effectively convert these notes to U.S. dollar–
# denominated notes.
# The effective interest rates for the Notes include the interest on the Notes, amortization of the discount or premium and, if
# applicable, adjustments related to hedging. The Company recogni zed $2.6 billion , $2.8 billion  and $3.2 billion  of interest expense
# on its term debt for 2021 , 2020  and 2019 , respectively.
# The future principal payments for the Company’s Notes as of September 25, 2021 , are as follows (in millions):
# 2022 $ 9,583
# 2023  11,391
# 2024  10,202
# 2025  10,914
# 2026  11,408
# Thereafter  64,565
# Total term debt $ 118,063
# As of September 25, 2021  and September 26, 2020 , the fair value of the Company’s Notes, based on Level 2 inputs, was $125.3
# billion  and $117.1 billion , respectively.
# Apple Inc. | 2021  Form 10-K | 45

# %%
query = "Impacts of the U.S. Tax Cuts and Jobs Act of 2017 on income taxes in 2020"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# The U.S. Tax Cuts and Jobs Act of 2017 had an impact on income taxes in 2020, as evidenced by a decrease in the provision for income taxes compared to the prior year.
# Retrieval entering b9416f35-ebf1-45d6-9a29-b59e435ab42d: TextNode
# Retrieving from object TextNode with query Impacts of the U.S. Tax Cuts and Jobs Act of 2017 on income taxes in 2020
# Retrieval entering 8d8d5733-ff30-4535-9376-7f761b5900ea: TextNode
# Retrieving from object TextNode with query Impacts of the U.S. Tax Cuts and Jobs Act of 2017 on income taxes in 2020
# Retrieval entering 82f301e5-199a-4aa2-bbdf-ef97898c0326: TextNode
# Retrieving from object TextNode with query Impacts of the U.S. Tax Cuts and Jobs Act of 2017 on income taxes in 2020
# Retrieval entering 86f666b4-254b-487f-9870-8ee09aef07a9: TextNode
# Retrieving from object TextNode with query Impacts of the U.S. Tax Cuts and Jobs Act of 2017 on income taxes in 2020
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# The U.S. Tax Cuts and Jobs Act of 2017 had a negative impact on income taxes in 2020.

# %%
print(response_1.source_nodes[0].get_content())
# Out:
# Other Income/(Expense), Net
# The following table shows the detail of OI&E for 2021 , 2020  and 2019  (in millions):
# 2021 2020 2019
# Interest and dividend income $ 2,843 $ 3,763 $ 4,961
# Interest expense  (2,645)  (2,873)  (3,576)
# Other income/(expense), net  60  (87)  422
# Total other income/(expense), net $ 258 $ 803 $ 1,807
# Note 5 – Income Taxe s
# Provision for Income Taxes and Effective  Tax Rat e
# The provision for income taxes for 2021 , 2020  and 2019 , consisted of the following (in millions):
# 2021 2020 2019
# Federal:
# Current $ 8,257 $ 6,306 $ 6,384
# Deferred  (7,176)  (3,619)  (2,939)
# Total  1,081  2,687  3,445
# State:
# Current  1,620  455  475
# Deferred  (338)  21  (67)
# Total  1,282  476  408
# Foreign:
# Current  9,424  3,134  3,962
# Deferred  2,740  3,383  2,666
# Total  12,164  6,517  6,628
# Provision for income taxes $ 14,527 $ 9,680 $ 10,481
# The foreign provision for income taxes is based on foreign pretax earnings of $68.7 billion , $38.1 billion  and $44.3 billion  in 2021 ,
# 2020  and 2019 , respectively.
# A reconciliation of the provision for income taxes, with the amount computed by applying the statutory federal income tax  rate
# (21% in 2021 , 2020  and 2019 ) to income before provision for income taxes for 2021 , 2020  and 2019 , is as follows (dollars in
# millions):
# 2021 2020 2019
# Computed expected tax $ 22,933 $ 14,089 $ 13,805
# State taxes, net of federal effect  1,151  423  423
# Impacts of the U.S. Tax Cuts and Jobs Act of 2017  —  (582)  —
# Earnings of foreign subsidiaries  (4,715)  (2,534)  (2,625)
# Foreign-derived intangible income deduction  (1,372)  (169)  (149)
# Research and development credit, net  (1,033)  (728)  (548)
# Excess tax benefits from equity awards  (2,137)  (930)  (639)
# Other  (300)  111  214
# Provision for income taxes $ 14,527 $ 9,680 $ 10,481
# Effective tax rate  13.3%  14.4%  15.9%
# Apple Inc. | 2021  Form 10-K | 41

# %%
query = "federal deferred tax in 2019-2021"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# $3,619 million in 2019, $7,176 million in 2020, and $1,081 million in 2021
# Retrieval entering 12b1355a-f9e6-4b08-a19a-3ffc00dc5b9f: TextNode
# Retrieving from object TextNode with query federal deferred tax in 2019-2021
# Retrieval entering 82f301e5-199a-4aa2-bbdf-ef97898c0326: TextNode
# Retrieving from object TextNode with query federal deferred tax in 2019-2021
# Retrieval entering 8d8d5733-ff30-4535-9376-7f761b5900ea: TextNode
# Retrieving from object TextNode with query federal deferred tax in 2019-2021
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# $2,939, $3,619, $7,176

# %%
query = "give me the deferred state income tax in 2019-2021 (include +/-)"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# State deferred income tax for 2019: $454 million
# State deferred income tax for 2020: $21 million
# State deferred income tax for 2021: -$338 million
# Retrieval entering 12b1355a-f9e6-4b08-a19a-3ffc00dc5b9f: TextNode
# Retrieving from object TextNode with query give me the deferred state income tax in 2019-2021 (include +/-)
# Retrieval entering 8d8d5733-ff30-4535-9376-7f761b5900ea: TextNode
# Retrieving from object TextNode with query give me the deferred state income tax in 2019-2021 (include +/-)
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# Deferred state income tax for the years 2019-2021:
# - 2019: ($67) million
# - 2020: $21 million
# - 2021: ($338) million

# %%
print(response_2.source_nodes[0].get_content())
# Out:
# Summary of income tax provisions for Federal, State, and Foreign entities over the years 2019, 2020, and 2021.,
# with the following table title:
# Income Tax Provisions by Entity and Year,
# with the following columns:
# - Entity: The type of entity (Federal, State, Foreign)
# - 2019: Income tax provisions for the year 2019
# - 2020: Income tax provisions for the year 2020
# - 2021: Income tax provisions for the year 2021
#
# | |2021|2020|2019|
# |---|---|---|---|
# |Federal:| | | |
# |Current|$8,257|$6,306|$6,384|
# |Deferred|(7,176)|(3,619)|(2,939)|
# |Total|1,081|2,687|3,445|
# |State:| | | |
# |Current|1,620|455|475|
# |Deferred|(338)|21|(67)|
# |Total|1,282|476|408|
# |Foreign:| | | |
# |Current|9,424|3,134|3,962|
# |Deferred|2,740|3,383|2,666|
# |Total|12,164|6,517|6,628|
# |Provision for income taxes|$14,527|$9,680|$10,481|

# %%
query = "current state taxes per year in 2019-2021 (include +/-)"

response_1 = raw_query_engine.query(query)
print("\n***********Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********Basic Query Engine***********
# $1,620 million in 2019, $455 million in 2020, $475 million in 2021
# Retrieval entering 82f301e5-199a-4aa2-bbdf-ef97898c0326: TextNode
# Retrieving from object TextNode with query current state taxes per year in 2019-2021 (include +/-)
# Retrieval entering 8d8d5733-ff30-4535-9376-7f761b5900ea: TextNode
# Retrieving from object TextNode with query current state taxes per year in 2019-2021 (include +/-)
# Retrieval entering b9416f35-ebf1-45d6-9a29-b59e435ab42d: TextNode
# Retrieving from object TextNode with query current state taxes per year in 2019-2021 (include +/-)
# Retrieval entering a029e464-575f-4dd6-afad-7cc0bbc5dbf9: TextNode
# Retrieving from object TextNode with query current state taxes per year in 2019-2021 (include +/-)
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# $475 in 2019, $455 in 2020, $1,620 in 2021.
